# %% [markdown]
# Business Rules:
# 1. Combine the data from both regions into a single table.

# %%
import pandas as pd

# %%
df1 = pd.read_csv("order_region_a(in).csv")

# %%
df1.head()
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
# 1  171-0001497-9165123  1.976030e+13                1      699.0
# 2  171-0002127-1363507  5.949760e+12                1      399.0
# 3  171-0002370-0601169  5.757190e+13                1      499.0
# 4  171-0004526-2028348  3.385130e+13                1     1699.0
#
#                             PromotionDiscount  batch_id
# 0    { "CurrencyCode": "INR", "Amount": "10"}       359
# 1  { "CurrencyCode": "INR", "Amount": "10.1"}      1135
# 2    { "CurrencyCode": "INR", "Amount": "10"}       297
# 3  { "CurrencyCode": "INR", "Amount": "10.1"}       114
# 4    { "CurrencyCode": "INR", "Amount": "10"}       764

# %%
df2 = pd.read_csv("order_region_b(in).csv")
df2.head(1)
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
#
#                           PromotionDiscount  batch_id
# 0  { "CurrencyCode": "INR", "Amount": "10"}       359

# %%
df2.shape
# Out:
# (44494, 6)

# %%
df1.shape
# Out:
# (44494, 6)

# %%
df1.columns
# Out:
# Index(['OrderId', 'OrderItemId', 'QuantityOrdered', 'ItemPrice',
#        'PromotionDiscount', 'batch_id'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['OrderId', 'OrderItemId', 'QuantityOrdered', 'ItemPrice',
#        'PromotionDiscount', 'batch_id'],
#       dtype='object')

# %%
pd.merge(df1,df2,on='OrderId',how='inner')
# Out:
#                    OrderId  OrderItemId_x  QuantityOrdered_x  ItemPrice_x  \
# 0      171-0001135-1657958   1.116890e+13                  1        949.0
# 1      171-0001497-9165123   1.976030e+13                  1        699.0
# 2      171-0002127-1363507   5.949760e+12                  1        399.0
# 3      171-0002370-0601169   5.757190e+13                  1        499.0
# 4      171-0004526-2028348   3.385130e+13                  1       1699.0
# ...                    ...            ...                ...          ...
# 54873  403-9398294-9729165   2.595270e+13                  1        899.0
# 54874  403-9398429-3695549   5.373600e+13                  1        499.0
# 54875  403-9399318-8267565   7.727720e+12                  1        499.0
# 54876  403-9400326-2753965   2.029820e+13                  1        499.0
# 54877  403-9400753-7822741   6.437950e+12                  1        629.0
#
#                               PromotionDiscount_x  batch_id_x  OrderItemId_y  \
# ...

# %%
pd.merge(df1,df2,on=['OrderId', 'OrderItemId', 'QuantityOrdered', 'ItemPrice','PromotionDiscount', 'batch_id'],how='inner')
# Out:
#                    OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0      171-0001135-1657958  1.116890e+13                1      949.0
# 1      171-0001497-9165123  1.976030e+13                1      699.0
# 2      171-0002127-1363507  5.949760e+12                1      399.0
# 3      171-0002370-0601169  5.757190e+13                1      499.0
# 4      171-0004526-2028348  3.385130e+13                1     1699.0
# ...                    ...           ...              ...        ...
# 44489  403-9398294-9729165  2.595270e+13                1      899.0
# 44490  403-9398429-3695549  5.373600e+13                1      499.0
# 44491  403-9399318-8267565  7.727720e+12                1      499.0
# 44492  403-9400326-2753965  2.029820e+13                1      499.0
# 44493  403-9400753-7822741  6.437950e+12                1      629.0
#
#                                 PromotionDiscount  batch_id
# 0        { "CurrencyCode": "INR", "Amount": "10"}       359
# ...

# %%
pd.concat([df1,df2],axis=0)
# Out:
#                    OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0      171-0001135-1657958  1.116890e+13                1      949.0
# 1      171-0001497-9165123  1.976030e+13                1      699.0
# 2      171-0002127-1363507  5.949760e+12                1      399.0
# 3      171-0002370-0601169  5.757190e+13                1      499.0
# 4      171-0004526-2028348  3.385130e+13                1     1699.0
# ...                    ...           ...              ...        ...
# 44489  403-9398294-9729165  2.595270e+13                1      899.0
# 44490  403-9398429-3695549  5.373600e+13                1      499.0
# 44491  403-9399318-8267565  7.727720e+12                1      499.0
# 44492  403-9400326-2753965  2.029820e+13                1      499.0
# 44493  403-9400753-7822741  6.437950e+12                1      629.0
#
#                                 PromotionDiscount  batch_id
# 0        { "CurrencyCode": "INR", "Amount": "10"}       359
# ...

# %%
df3 = pd.merge(df1,df2,on=['OrderId', 'OrderItemId', 'QuantityOrdered', 'ItemPrice','PromotionDiscount', 'batch_id'],how='inner')
df3.head()
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
# 1  171-0001497-9165123  1.976030e+13                1      699.0
# 2  171-0002127-1363507  5.949760e+12                1      399.0
# 3  171-0002370-0601169  5.757190e+13                1      499.0
# 4  171-0004526-2028348  3.385130e+13                1     1699.0
#
#                             PromotionDiscount  batch_id
# 0    { "CurrencyCode": "INR", "Amount": "10"}       359
# 1  { "CurrencyCode": "INR", "Amount": "10.1"}      1135
# 2    { "CurrencyCode": "INR", "Amount": "10"}       297
# 3  { "CurrencyCode": "INR", "Amount": "10.1"}       114
# 4    { "CurrencyCode": "INR", "Amount": "10"}       764

# %% [markdown]
# why I merged because order_a and order_b value containing same values so merged insted of combining.

# %% [markdown]
# Add a column total_sales which is calculated as QuantityOrdered *
# ItemPrice.

# %%
df3['total_sales'] = df3['QuantityOrdered'] * df3['ItemPrice']
df3.head()
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
# 1  171-0001497-9165123  1.976030e+13                1      699.0
# 2  171-0002127-1363507  5.949760e+12                1      399.0
# 3  171-0002370-0601169  5.757190e+13                1      499.0
# 4  171-0004526-2028348  3.385130e+13                1     1699.0
#
#                             PromotionDiscount  batch_id  total_sales
# 0    { "CurrencyCode": "INR", "Amount": "10"}       359        949.0
# 1  { "CurrencyCode": "INR", "Amount": "10.1"}      1135        699.0
# 2    { "CurrencyCode": "INR", "Amount": "10"}       297        399.0
# 3  { "CurrencyCode": "INR", "Amount": "10.1"}       114        499.0
# 4    { "CurrencyCode": "INR", "Amount": "10"}       764       1699.0

# %%
df1['total_sales'] = df1['QuantityOrdered'] * df1['ItemPrice']   #order a
df1.head()
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
# 1  171-0001497-9165123  1.976030e+13                1      699.0
# 2  171-0002127-1363507  5.949760e+12                1      399.0
# 3  171-0002370-0601169  5.757190e+13                1      499.0
# 4  171-0004526-2028348  3.385130e+13                1     1699.0
#
#                             PromotionDiscount  batch_id  total_sales
# 0    { "CurrencyCode": "INR", "Amount": "10"}       359        949.0
# 1  { "CurrencyCode": "INR", "Amount": "10.1"}      1135        699.0
# 2    { "CurrencyCode": "INR", "Amount": "10"}       297        399.0
# 3  { "CurrencyCode": "INR", "Amount": "10.1"}       114        499.0
# 4    { "CurrencyCode": "INR", "Amount": "10"}       764       1699.0

# %%
df2['total_sales'] = df2['QuantityOrdered'] * df2['ItemPrice']   #order b
df2.head()
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
# 1  171-0001497-9165123  1.976030e+13                1      699.0
# 2  171-0002127-1363507  5.949760e+12                1      399.0
# 3  171-0002370-0601169  5.757190e+13                1      499.0
# 4  171-0004526-2028348  3.385130e+13                1     1699.0
#
#                             PromotionDiscount  batch_id  total_sales
# 0    { "CurrencyCode": "INR", "Amount": "10"}       359        949.0
# 1  { "CurrencyCode": "INR", "Amount": "10.1"}      1135        699.0
# 2    { "CurrencyCode": "INR", "Amount": "10"}       297        399.0
# 3  { "CurrencyCode": "INR", "Amount": "10.1"}       114        499.0
# 4    { "CurrencyCode": "INR", "Amount": "10"}       764       1699.0

# %% [markdown]
# Add a column region to identify the region of the sales record (A or B).

# %%
pd.concat([df1,df2],axis=0)
# Out:
#                    OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0      171-0001135-1657958  1.116890e+13                1      949.0
# 1      171-0001497-9165123  1.976030e+13                1      699.0
# 2      171-0002127-1363507  5.949760e+12                1      399.0
# 3      171-0002370-0601169  5.757190e+13                1      499.0
# 4      171-0004526-2028348  3.385130e+13                1     1699.0
# ...                    ...           ...              ...        ...
# 44489  403-9398294-9729165  2.595270e+13                1      899.0
# 44490  403-9398429-3695549  5.373600e+13                1      499.0
# 44491  403-9399318-8267565  7.727720e+12                1      499.0
# 44492  403-9400326-2753965  2.029820e+13                1      499.0
# 44493  403-9400753-7822741  6.437950e+12                1      629.0
#
#                                 PromotionDiscount  batch_id
# 0        { "CurrencyCode": "INR", "Amount": "10"}       359
# ...

# %%
pd.concat([df1,df2],axis=0)
# Out:
#                    OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0      171-0001135-1657958  1.116890e+13                1      949.0
# 1      171-0001497-9165123  1.976030e+13                1      699.0
# 2      171-0002127-1363507  5.949760e+12                1      399.0
# 3      171-0002370-0601169  5.757190e+13                1      499.0
# 4      171-0004526-2028348  3.385130e+13                1     1699.0
# ...                    ...           ...              ...        ...
# 44489  403-9398294-9729165  2.595270e+13                1      899.0
# 44490  403-9398429-3695549  5.373600e+13                1      499.0
# 44491  403-9399318-8267565  7.727720e+12                1      499.0
# 44492  403-9400326-2753965  2.029820e+13                1      499.0
# 44493  403-9400753-7822741  6.437950e+12                1      629.0
#
#                                 PromotionDiscount  batch_id
# 0        { "CurrencyCode": "INR", "Amount": "10"}       359
# ...

# %% [markdown]
# Ensure that there are no duplicate entries based on OrderId.

# %%
df1.duplicated('OrderId').sum() #order a
# Out:
# np.int64(3387)

# %%
df2.duplicated('OrderId').sum() #order b
# Out:
# np.int64(3387)

# %%
df3.duplicated('OrderId').sum() #merge a and b
# Out:
# np.int64(3387)

# %%
df1.drop_duplicates('OrderId',inplace=True)

# %%
df1.duplicated('OrderId').sum()
# Out:
# np.int64(0)

# %%
df1.shape
# Out:
# (41107, 6)

# %%
df2.drop_duplicates('OrderId',inplace=True)

# %%
df2.duplicated('OrderId').sum()
# Out:
# np.int64(0)

# %%
df3.drop_duplicates('OrderId',inplace=True)

# %%
df3.duplicated('OrderId').sum()
# Out:
# np.int64(0)

# %% [markdown]
# Add a new column net_sale, calculated as total_sales - PromotionDiscount.

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41107 entries, 0 to 44493
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   OrderId            41107 non-null  object
#  1   OrderItemId        41107 non-null  float64
#  2   QuantityOrdered    41107 non-null  int64
#  3   ItemPrice          41107 non-null  float64
#  4   PromotionDiscount  41107 non-null  object
#  5   batch_id           41107 non-null  int64
#  6   total_sales        41107 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 2.5+ MB

# %%
df3.head(2)
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
# 1  171-0001497-9165123  1.976030e+13                1      699.0
#
#                             PromotionDiscount  batch_id  total_sales
# 0    { "CurrencyCode": "INR", "Amount": "10"}       359        949.0
# 1  { "CurrencyCode": "INR", "Amount": "10.1"}      1135        699.0

# %%
df3['PromotionDiscount'].value_counts()
# Out:
# PromotionDiscount
# { "CurrencyCode": "INR", "Amount": "10.1"}    20559
# { "CurrencyCode": "INR", "Amount": "10"}      20548
# Name: count, dtype: int64

# %%
df3['pd'] = df3['PromotionDiscount'].str[36:38].astype('float64')
df3.head(2)
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
# 1  171-0001497-9165123  1.976030e+13                1      699.0
#
#                             PromotionDiscount  batch_id  total_sales    pd
# 0    { "CurrencyCode": "INR", "Amount": "10"}       359        949.0  10.0
# 1  { "CurrencyCode": "INR", "Amount": "10.1"}      1135        699.0  10.0

# %%
df3['net_sale'] = df3['total_sales'] - df3['pd']
df3.head(2)
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
# 1  171-0001497-9165123  1.976030e+13                1      699.0
#
#                             PromotionDiscount  batch_id  total_sales    pd  \
# 0    { "CurrencyCode": "INR", "Amount": "10"}       359        949.0  10.0
# 1  { "CurrencyCode": "INR", "Amount": "10.1"}      1135        699.0  10.0
#
#    net_sale
# 0     939.0
# 1     689.0

# %%
df1['PromotionDiscount'].value_counts() #order a
# Out:
# PromotionDiscount
# { "CurrencyCode": "INR", "Amount": "10.1"}    20559
# { "CurrencyCode": "INR", "Amount": "10"}      20548
# Name: count, dtype: int64

# %%
df1['pd'] = df1['PromotionDiscount'].str[36:38].astype('float64')
df1.head(2)
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
# 1  171-0001497-9165123  1.976030e+13                1      699.0
#
#                             PromotionDiscount  batch_id  total_sales    pd
# 0    { "CurrencyCode": "INR", "Amount": "10"}       359        949.0  10.0
# 1  { "CurrencyCode": "INR", "Amount": "10.1"}      1135        699.0  10.0

# %%
df1['net_sale'] = df1['total_sales'] - df1['pd']
df1.head(2)
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
# 1  171-0001497-9165123  1.976030e+13                1      699.0
#
#                             PromotionDiscount  batch_id  total_sales    pd  \
# 0    { "CurrencyCode": "INR", "Amount": "10"}       359        949.0  10.0
# 1  { "CurrencyCode": "INR", "Amount": "10.1"}      1135        699.0  10.0
#
#    net_sale
# 0     939.0
# 1     689.0

# %%
df2['PromotionDiscount'].value_counts() #order b
# Out:
# PromotionDiscount
# { "CurrencyCode": "INR", "Amount": "10.1"}    20559
# { "CurrencyCode": "INR", "Amount": "10"}      20548
# Name: count, dtype: int64

# %%
df2['pd'] = df2['PromotionDiscount'].str[36:38].astype('float64')
df2.head(2)
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
# 1  171-0001497-9165123  1.976030e+13                1      699.0
#
#                             PromotionDiscount  batch_id  total_sales    pd
# 0    { "CurrencyCode": "INR", "Amount": "10"}       359        949.0  10.0
# 1  { "CurrencyCode": "INR", "Amount": "10.1"}      1135        699.0  10.0

# %%
df2['net_sale'] = df2['total_sales'] - df2['pd']
df2.head(2)
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
# 1  171-0001497-9165123  1.976030e+13                1      699.0
#
#                             PromotionDiscount  batch_id  total_sales    pd  \
# 0    { "CurrencyCode": "INR", "Amount": "10"}       359        949.0  10.0
# 1  { "CurrencyCode": "INR", "Amount": "10.1"}      1135        699.0  10.0
#
#    net_sale
# 0     939.0
# 1     689.0

# %% [markdown]
# Exclude orders where the total sales amount is negative or zero after applying
# discounts.

# %%
# after applying discounts means it is net_sale
df3[df3['net_sale']<=0]['net_sale'].shape
# Out:
# (55,)

# %%
df3[df3['net_sale']>0]
# Out:
#                    OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0      171-0001135-1657958  1.116890e+13                1      949.0
# 1      171-0001497-9165123  1.976030e+13                1      699.0
# 2      171-0002127-1363507  5.949760e+12                1      399.0
# 3      171-0002370-0601169  5.757190e+13                1      499.0
# 4      171-0004526-2028348  3.385130e+13                1     1699.0
# ...                    ...           ...              ...        ...
# 44489  403-9398294-9729165  2.595270e+13                1      899.0
# 44490  403-9398429-3695549  5.373600e+13                1      499.0
# 44491  403-9399318-8267565  7.727720e+12                1      499.0
# 44492  403-9400326-2753965  2.029820e+13                1      499.0
# 44493  403-9400753-7822741  6.437950e+12                1      629.0
#
#                                 PromotionDiscount  batch_id  total_sales  \
# ...

# %%
df3 = df3[df3['net_sale']>0]

# %%
df3.head(1)
# Out:
#                OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0  171-0001135-1657958  1.116890e+13                1      949.0
#
#                           PromotionDiscount  batch_id  total_sales    pd  \
# 0  { "CurrencyCode": "INR", "Amount": "10"}       359        949.0  10.0
#
#    net_sale
# 0     939.0

# %%
df3.shape
# Out:
# (41052, 9)

# %%
# after applying discounts means it is net_sale   order a
df1[df1['net_sale']<=0]['net_sale'].shape
# Out:
# (55,)

# %%
df1 = df1[df1['net_sale']>0]

# %%
df1.shape
# Out:
# (41052, 9)

# %%
# after applying discounts means it is net_sale   order b
df2[df2['net_sale']<=0]['net_sale'].shape
# Out:
# (55,)

# %%
df2 = df2[df2['net_sale']>0]

# %%
df2.shape
# Out:
# (41052, 9)

# %% [markdown]
# Ensure data is cleaned, and all business rules are applied (including removal of
# duplicates and filtering based on net_sales).

# %%
df3.isnull().sum()
# Out:
# OrderId              0
# OrderItemId          0
# QuantityOrdered      0
# ItemPrice            0
# PromotionDiscount    0
# batch_id             0
# total_sales          0
# pd                   0
# net_sale             0
# dtype: int64

# %%
# Exclude orders where the total sales amount is negative or zero after applying discounts.
# Filtering is done on based of net_sales

# %% [markdown]
# 3. Load Data:
# a. Create a table sales_data.

# %%
df1.shape
# Out:
# (41052, 9)

# %%
df2.shape
# Out:
# (41052, 9)

# %%
df3.shape
# Out:
# (41052, 9)

# %%
pd.concat([df1,df2],axis=0)
# Out:
#                    OrderId   OrderItemId  QuantityOrdered  ItemPrice  \
# 0      171-0001135-1657958  1.116890e+13                1      949.0
# 1      171-0001497-9165123  1.976030e+13                1      699.0
# 2      171-0002127-1363507  5.949760e+12                1      399.0
# 3      171-0002370-0601169  5.757190e+13                1      499.0
# 4      171-0004526-2028348  3.385130e+13                1     1699.0
# ...                    ...           ...              ...        ...
# 44489  403-9398294-9729165  2.595270e+13                1      899.0
# 44490  403-9398429-3695549  5.373600e+13                1      499.0
# 44491  403-9399318-8267565  7.727720e+12                1      499.0
# 44492  403-9400326-2753965  2.029820e+13                1      499.0
# 44493  403-9400753-7822741  6.437950e+12                1      629.0
#
#                                 PromotionDiscount  batch_id  total_sales  \
# ...

# %%
df3.to_csv("sales_data.csv")

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41052 entries, 0 to 44493
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   OrderId            41052 non-null  object
#  1   OrderItemId        41052 non-null  float64
#  2   QuantityOrdered    41052 non-null  int64
#  3   ItemPrice          41052 non-null  float64
#  4   PromotionDiscount  41052 non-null  object
#  5   batch_id           41052 non-null  int64
#  6   total_sales        41052 non-null  float64
#  7   pd                 41052 non-null  float64
#  8   net_sale           41052 non-null  float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 3.1+ MB
